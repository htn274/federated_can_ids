# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
list(range(int(1e4), int(5e4)+10, int(1e4)))
# Out:
# [10000, 20000, 30000, 40000, 50000]

# %%
f1_results = pd.DataFrame({
    'Kia': [ 0.9873, 0.9937, 0.9937, 0.9939, 0.9952],
    'Tesla': [ 0.9725, 0.9746, 0.9847, 0.9914, 0.9922],
    'BMW' : [ 0.6918, 0.8117, 0.9263, 0.9387, 0.9806]
}, index =range(int(1e4), int(5e4)+10, int(1e4)))

# %%
f1_results['Avg'] = f1_results['Kia'] + f1_results['Tesla'] + f1_results['BMW']
f1_results['Avg'] = f1_results['Avg'] / 3
f1_results
# Out:
#           Kia   Tesla     BMW       Avg
# 10000  0.9873  0.9725  0.6918  0.883867
# 20000  0.9937  0.9746  0.8117  0.926667
# 30000  0.9937  0.9847  0.9263  0.968233
# 40000  0.9939  0.9914  0.9387  0.974667
# 50000  0.9952  0.9922  0.9806  0.989333

# %%
plt.figure(figsize=(15,8), dpi=300)
sns.lineplot(data=f1_results, markers=True)
# Out:
# <AxesSubplot:>
